# %% [markdown]
# 1. What geom would you use to draw a line chart? A boxplot? A histogram? An area chart?
#
# Line chart: geom_line()
# Boxplot: geom_boxplot()
# Histogram: geom_histogram()
# Area Chart: geom_area()

# %% [markdown]
# 2.Run this code in your head and predict what the output will look like. Then, run the code in R and check your predictions.
#
# There will be a plot of displ and hwy with colours, the mapping is defined in ggplot hence all will be displayed.

# %%
library(tidyverse)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.1.1       ✔ purrr   0.3.2
# ✔ tibble  2.1.1       ✔ dplyr   0.8.0.1
# ✔ tidyr   0.8.3       ✔ stringr 1.4.0
# ✔ readr   1.3.1       ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy, color = drv)) + 
  geom_point() + 
  geom_smooth(se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %% [markdown]
# 3. What does show.legend = FALSE do? What happens if you remove it? Why do you think I used it earlier in the chapter?
#
# It removes the legend that is automaticaly created when ploting e.g color .
# If the argument is removed legend will show since it will be True

# %% [markdown]
# 4. What does the se argument to geom_smooth() do?
#
# It is responsible for displaying the confidence intervals around smooth

# %% [markdown]
# 5. Will these two graphs look different? Why/why not?
#
# Yes the graphs will look the same. Its just that in the second graph data is defined separately in each geom while in the first data is defined for both.

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) + 
  geom_point() + 
  geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot() + 
  geom_point(data = mpg, mapping = aes(x = displ, y = hwy)) + 
  geom_smooth(data = mpg, mapping = aes(x = displ, y = hwy))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %% [markdown]
# 6. Recreate the R code necessary to generate the following graphs.

# %%
ggplot(data = mpg, mapping = aes(y = hwy, x = displ)) + 
  geom_point() +
  geom_smooth(se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(data = mpg, mapping = aes(y = hwy, x = displ)) + 
  geom_point() +
  geom_smooth(mapping = aes(group = drv), se = FALSE, show.legend = FALSE)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(data = mpg, mapping = aes(y = hwy, x = displ)) + 
  geom_point(mapping = aes(color = drv)) +
  geom_smooth(mapping = aes(color = drv, group = drv), se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(data = mpg, mapping = aes(y = hwy, x = displ)) + 
  geom_point(mapping = aes(color = drv)) +
  geom_smooth(se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(data = mpg, mapping = aes(y = hwy, x = displ)) + 
  geom_point(mapping = aes(color = drv)) +
  geom_smooth(mapping = aes(linetype = drv), se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(data = mpg, mapping = aes(y = hwy, x = displ)) + 
  geom_point(mapping = aes(fill = drv), color = 'white', stroke = 4, shape = 21)
# Out:
# plot without title
