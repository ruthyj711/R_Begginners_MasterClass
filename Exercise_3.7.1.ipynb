# %% [markdown]
# 1. What is the default geom associated with stat_summary()? How could you rewrite the previous plot to use that geom function instead of the stat function?
#
# The default is geom_pointrange()
# The plot could be rewriten by use of geom_pointrange()

# %%
library(tidyverse)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.1.1       ✔ purrr   0.3.2
# ✔ tibble  2.1.1       ✔ dplyr   0.8.0.1
# ✔ tidyr   0.8.3       ✔ stringr 1.4.0
# ✔ readr   1.3.1       ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
#rewriten code 
ggplot(data = diamonds) + 
  geom_pointrange(
    mapping = aes(x = cut, y = depth),
    stat = "summary",
    fun.ymin = min,
    fun.ymax = max,
    fun.y = median
  )
# Out:
# plot without title

# %% [markdown]
# 2. What does geom_col() do? How is it different to geom_bar()?
#
# geom_col()used to plot values is data set it also plots a bar chat
# geom_col() is used to represent value in the data while geom_bar() makes the height proportional to the number given

# %% [markdown]
# 3. Most geoms and stats come in pairs that are almost always used in concert. Read through the documentation and make a list of all the pairs. What do they have in common?

# %% [markdown]
# 4. What variables does stat_smooth() compute? What parameters control its behaviour?
#
# It calculates
# y prediced value
# ymin: lower value of confidence interval
# ymax: upper value of confidence interval
# Standard error

# %% [markdown]
# 5. In our proportion bar chart, we need to set group = 1. Why? In other words what is the problem with these two graphs?
#
# If group is not set to 1, then all the bars will be set to 1. The function geom_bar assumes that the groups are equal to the x values, since the stat computes the counts within the group.

# %%
ggplot(data = diamonds) + 
  geom_bar(mapping = aes(x = cut, y = ..prop..))
# Out:
# plot without title

# %%
ggplot(data = diamonds) + 
  geom_bar(mapping = aes(x = cut, fill = color, y = ..prop..))
# Out:
# plot without title
