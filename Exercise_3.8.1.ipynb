# %%
library(tidyverse)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.1.1       ✔ purrr   0.3.2
# ✔ tibble  2.1.1       ✔ dplyr   0.8.0.1
# ✔ tidyr   0.8.3       ✔ stringr 1.4.0
# ✔ readr   1.3.1       ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# 1. What is the problem with this plot? How could you improve it?
#
# Cty and hwy have the same values so the ploting is not visible as it should.
# geom_jitter() makes it better by adding randomnes to it

# %%
ggplot(data = mpg, mapping = aes(x = cty, y = hwy)) + 
  geom_point()
# Out:
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = cty, y = hwy)) + 
  geom_jitter()
# Out:
# plot without title

# %% [markdown]
# 2. What parameters to geom_jitter() control the amount of jittering?
#
# width and height

# %% [markdown]
# 3. Compare and contrast geom_jitter() with geom_count()
# In case of overploting geom_jitter() and geom_count() makes them more visible.
# geom_jitter() Adjusts the position while geom_count() counts the overlaping points

# %% [markdown]
# 4. What’s the default position adjustment for geom_boxplot()? Create a visualisation of the mpg dataset that demonstrates it.

# %%
ggplot(data=mpg)+
    geom_boxplot(mapping= aes(y=displ, x=cyl, color=drv))
# Out:
# plot without title
