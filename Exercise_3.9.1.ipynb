# %%
library(tidyverse)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.1.1       ✔ purrr   0.3.2
# ✔ tibble  2.1.1       ✔ dplyr   0.8.0.1
# ✔ tidyr   0.8.3       ✔ stringr 1.4.0
# ✔ readr   1.3.1       ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# 1. Turn a stacked bar chart into a pie chart using coord_polar().

# %%
ggplot(data = diamonds) + 
  geom_bar(mapping = aes(x = cut, fill = color)) +
    coord_polar()
# Out:
# plot without title

# %% [markdown]
# 2. What does labs() do?
#
# It is used to modify axis,legends and plots labels

# %% [markdown]
# 3. What’s the difference between coord_quickmap() and coord_map()?    (?coord_map)
#
# coord_map() projects a portion of the earth which is spherical onto a flat 2D plane
# Coord_quickmap() is a quick approximation that does preserve straight lines

# %% [markdown]
# 4. What does the plot below tell you about the relationship between city and highway mpg? Why is coord_fixed() important? What does geom_abline() do?
#
# THe line shows a positive relationship,a unit increase in cty brings about an increase in hwy
# coord_fixed() it creates a coordinate system with a specified aspect ratio
# geom_abline() it adds a line with specified slops and intercepts to the plot

# %%
ggplot(data = mpg, mapping = aes(x = cty, y = hwy)) +
  geom_point() + 
  geom_abline() +
  coord_fixed()
# Out:
# plot without title
